# %%
#Packages
import numpy as np
import pandas as pd

# %%
#Yahoo Finance - yfinance API Data Source
import yfinance as yf

# %%
#Set variables for all 500 ticker symbols to get live price by 1 day by 1 minute
MMM = yf.download(tickers= " MMM ", period='1d', interval='1m')
ABT = yf.download(tickers= " ABT ", period='1d', interval='1m')
ABBV = yf.download(tickers= " ABBV ", period='1d', interval='1m')
ABMD = yf.download(tickers= " ABMD ", period='1d', interval='1m')
ACN = yf.download(tickers= " ACN ", period='1d', interval='1m')
ATVI = yf.download(tickers= " ATVI ", period='1d', interval='1m')
ADBE = yf.download(tickers= " ADBE ", period='1d', interval='1m')
AMD = yf.download(tickers= " AMD ", period='1d', interval='1m')
AAP = yf.download(tickers= " AAP ", period='1d', interval='1m')
AES = yf.download(tickers= " AES ", period='1d', interval='1m')
AFL = yf.download(tickers= " AFL ", period='1d', interval='1m')
A = yf.download(tickers= " A ", period='1d', interval='1m')
APD = yf.download(tickers= " APD ", period='1d', interval='1m')
AKAM = yf.download(tickers= " AKAM ", period='1d', interval='1m')
ALK = yf.download(tickers= " ALK ", period='1d', interval='1m')
ALB = yf.download(tickers= " ALB ", period='1d', interval='1m')
ARE = yf.download(tickers= " ARE ", period='1d', interval='1m')
ALXN = yf.download(tickers= " ALXN ", period='1d', interval='1m')
ALGN = yf.download(tickers= " ALGN ", period='1d', interval='1m')
ALLE = yf.download(tickers= " ALLE ", period='1d', interval='1m')
LNT = yf.download(tickers= " LNT ", period='1d', interval='1m')
ALL = yf.download(tickers= " ALL ", period='1d', interval='1m')
GOOGL = yf.download(tickers= " GOOGL ", period='1d', interval='1m')
GOOG = yf.download(tickers= " GOOG ", period='1d', interval='1m')
MO = yf.download(tickers= " MO ", period='1d', interval='1m')
AMZN = yf.download(tickers= " AMZN ", period='1d', interval='1m')
AMCR = yf.download(tickers= " AMCR ", period='1d', interval='1m')
AEE = yf.download(tickers= " AEE ", period='1d', interval='1m')
AAL = yf.download(tickers= " AAL ", period='1d', interval='1m')
AEP = yf.download(tickers= " AEP ", period='1d', interval='1m')
AXP = yf.download(tickers= " AXP ", period='1d', interval='1m')
AIG = yf.download(tickers= " AIG ", period='1d', interval='1m')
AMT = yf.download(tickers= " AMT ", period='1d', interval='1m')
AWK = yf.download(tickers= " AWK ", period='1d', interval='1m')
AMP = yf.download(tickers= " AMP ", period='1d', interval='1m')
ABC = yf.download(tickers= " ABC ", period='1d', interval='1m')
AME = yf.download(tickers= " AME ", period='1d', interval='1m')
AMGN = yf.download(tickers= " AMGN ", period='1d', interval='1m')
APH = yf.download(tickers= " APH ", period='1d', interval='1m')
ADI = yf.download(tickers= " ADI ", period='1d', interval='1m')
ANSS = yf.download(tickers= " ANSS ", period='1d', interval='1m')
ANTM = yf.download(tickers= " ANTM ", period='1d', interval='1m')
AON = yf.download(tickers= " AON ", period='1d', interval='1m')
AOS = yf.download(tickers= " AOS ", period='1d', interval='1m')
APA = yf.download(tickers= " APA ", period='1d', interval='1m')
AAPL = yf.download(tickers= " AAPL ", period='1d', interval='1m')
AMAT = yf.download(tickers= " AMAT ", period='1d', interval='1m')
APTV = yf.download(tickers= " APTV ", period='1d', interval='1m')
ADM = yf.download(tickers= " ADM ", period='1d', interval='1m')
ANET = yf.download(tickers= " ANET ", period='1d', interval='1m')
AJG = yf.download(tickers= " AJG ", period='1d', interval='1m')
AIZ = yf.download(tickers= " AIZ ", period='1d', interval='1m')
T = yf.download(tickers= " T ", period='1d', interval='1m')
ATO = yf.download(tickers= " ATO ", period='1d', interval='1m')
ADSK = yf.download(tickers= " ADSK ", period='1d', interval='1m')
ADP = yf.download(tickers= " ADP ", period='1d', interval='1m')
AZO = yf.download(tickers= " AZO ", period='1d', interval='1m')
AVB = yf.download(tickers= " AVB ", period='1d', interval='1m')
AVY = yf.download(tickers= " AVY ", period='1d', interval='1m')
BKR = yf.download(tickers= " BKR ", period='1d', interval='1m')
BLL = yf.download(tickers= " BLL ", period='1d', interval='1m')
BAC = yf.download(tickers= " BAC ", period='1d', interval='1m')
BK = yf.download(tickers= " BK ", period='1d', interval='1m')
BAX = yf.download(tickers= " BAX ", period='1d', interval='1m')
BDX = yf.download(tickers= " BDX ", period='1d', interval='1m')
BRKB = yf.download(tickers= " BRKB ", period='1d', interval='1m')
BBY = yf.download(tickers= " BBY ", period='1d', interval='1m')
BIO = yf.download(tickers= " BIO ", period='1d', interval='1m')
BIIB = yf.download(tickers= " BIIB ", period='1d', interval='1m')
BLK = yf.download(tickers= " BLK ", period='1d', interval='1m')
BA = yf.download(tickers= " BA ", period='1d', interval='1m')
BKNG = yf.download(tickers= " BKNG ", period='1d', interval='1m')
BWA = yf.download(tickers= " BWA ", period='1d', interval='1m')
BXP = yf.download(tickers= " BXP ", period='1d', interval='1m')
BSX = yf.download(tickers= " BSX ", period='1d', interval='1m')
BMY = yf.download(tickers= " BMY ", period='1d', interval='1m')
AVGO = yf.download(tickers= " AVGO ", period='1d', interval='1m')
BR = yf.download(tickers= " BR ", period='1d', interval='1m')
BFB = yf.download(tickers= " BFB ", period='1d', interval='1m')
CHRW = yf.download(tickers= " CHRW ", period='1d', interval='1m')
COG = yf.download(tickers= " COG ", period='1d', interval='1m')
CDNS = yf.download(tickers= " CDNS ", period='1d', interval='1m')
CPB = yf.download(tickers= " CPB ", period='1d', interval='1m')
COF = yf.download(tickers= " COF ", period='1d', interval='1m')
CAH = yf.download(tickers= " CAH ", period='1d', interval='1m')
KMX = yf.download(tickers= " KMX ", period='1d', interval='1m')
CCL = yf.download(tickers= " CCL ", period='1d', interval='1m')
CARR = yf.download(tickers= " CARR ", period='1d', interval='1m')
CTLT = yf.download(tickers= " CTLT ", period='1d', interval='1m')
CAT = yf.download(tickers= " CAT ", period='1d', interval='1m')
CBOE = yf.download(tickers= " CBOE ", period='1d', interval='1m')
CBRE = yf.download(tickers= " CBRE ", period='1d', interval='1m')
CDW = yf.download(tickers= " CDW ", period='1d', interval='1m')
CE = yf.download(tickers= " CE ", period='1d', interval='1m')
CNC = yf.download(tickers= " CNC ", period='1d', interval='1m')
CNP = yf.download(tickers= " CNP ", period='1d', interval='1m')
CERN = yf.download(tickers= " CERN ", period='1d', interval='1m')
CF = yf.download(tickers= " CF ", period='1d', interval='1m')
SCHW = yf.download(tickers= " SCHW ", period='1d', interval='1m')
CHTR = yf.download(tickers= " CHTR ", period='1d', interval='1m')
CVX = yf.download(tickers= " CVX ", period='1d', interval='1m')
CMG = yf.download(tickers= " CMG ", period='1d', interval='1m')
CB = yf.download(tickers= " CB ", period='1d', interval='1m')
CHD = yf.download(tickers= " CHD ", period='1d', interval='1m')
CI = yf.download(tickers= " CI ", period='1d', interval='1m')
CINF = yf.download(tickers= " CINF ", period='1d', interval='1m')
CTAS = yf.download(tickers= " CTAS ", period='1d', interval='1m')
CSCO = yf.download(tickers= " CSCO ", period='1d', interval='1m')
C = yf.download(tickers= " C ", period='1d', interval='1m')
CFG = yf.download(tickers= " CFG ", period='1d', interval='1m')
CTXS = yf.download(tickers= " CTXS ", period='1d', interval='1m')
CLX = yf.download(tickers= " CLX ", period='1d', interval='1m')
CME = yf.download(tickers= " CME ", period='1d', interval='1m')
CMS = yf.download(tickers= " CMS ", period='1d', interval='1m')
KO = yf.download(tickers= " KO ", period='1d', interval='1m')
CTSH = yf.download(tickers= " CTSH ", period='1d', interval='1m')
CL = yf.download(tickers= " CL ", period='1d', interval='1m')
CMCSA = yf.download(tickers= " CMCSA ", period='1d', interval='1m')
CMA = yf.download(tickers= " CMA ", period='1d', interval='1m')
CAG = yf.download(tickers= " CAG ", period='1d', interval='1m')
CXO = yf.download(tickers= " CXO ", period='1d', interval='1m')
COP = yf.download(tickers= " COP ", period='1d', interval='1m')
ED = yf.download(tickers= " ED ", period='1d', interval='1m')
STZ = yf.download(tickers= " STZ ", period='1d', interval='1m')
COO = yf.download(tickers= " COO ", period='1d', interval='1m')
CPRT = yf.download(tickers= " CPRT ", period='1d', interval='1m')
GLW = yf.download(tickers= " GLW ", period='1d', interval='1m')
CTVA = yf.download(tickers= " CTVA ", period='1d', interval='1m')
COST = yf.download(tickers= " COST ", period='1d', interval='1m')
CCI = yf.download(tickers= " CCI ", period='1d', interval='1m')
CSX = yf.download(tickers= " CSX ", period='1d', interval='1m')
CMI = yf.download(tickers= " CMI ", period='1d', interval='1m')
CVS = yf.download(tickers= " CVS ", period='1d', interval='1m')
DHI = yf.download(tickers= " DHI ", period='1d', interval='1m')
DHR = yf.download(tickers= " DHR ", period='1d', interval='1m')
DRI = yf.download(tickers= " DRI ", period='1d', interval='1m')
DVA = yf.download(tickers= " DVA ", period='1d', interval='1m')
DE = yf.download(tickers= " DE ", period='1d', interval='1m')
DAL = yf.download(tickers= " DAL ", period='1d', interval='1m')
XRAY = yf.download(tickers= " XRAY ", period='1d', interval='1m')
DVN = yf.download(tickers= " DVN ", period='1d', interval='1m')
DXCM = yf.download(tickers= " DXCM ", period='1d', interval='1m')
FANG = yf.download(tickers= " FANG ", period='1d', interval='1m')
DLR = yf.download(tickers= " DLR ", period='1d', interval='1m')
DFS = yf.download(tickers= " DFS ", period='1d', interval='1m')
DISCA = yf.download(tickers= " DISCA ", period='1d', interval='1m')
DISCK = yf.download(tickers= " DISCK ", period='1d', interval='1m')
DISH = yf.download(tickers= " DISH ", period='1d', interval='1m')
DG = yf.download(tickers= " DG ", period='1d', interval='1m')
DLTR = yf.download(tickers= " DLTR ", period='1d', interval='1m')
D = yf.download(tickers= " D ", period='1d', interval='1m')
DPZ = yf.download(tickers= " DPZ ", period='1d', interval='1m')
DOV = yf.download(tickers= " DOV ", period='1d', interval='1m')
DOW = yf.download(tickers= " DOW ", period='1d', interval='1m')
DTE = yf.download(tickers= " DTE ", period='1d', interval='1m')
DUK = yf.download(tickers= " DUK ", period='1d', interval='1m')
DRE = yf.download(tickers= " DRE ", period='1d', interval='1m')
DD = yf.download(tickers= " DD ", period='1d', interval='1m')
DXC = yf.download(tickers= " DXC ", period='1d', interval='1m')
EMN = yf.download(tickers= " EMN ", period='1d', interval='1m')
ETN = yf.download(tickers= " ETN ", period='1d', interval='1m')
EBAY = yf.download(tickers= " EBAY ", period='1d', interval='1m')
ECL = yf.download(tickers= " ECL ", period='1d', interval='1m')
EIX = yf.download(tickers= " EIX ", period='1d', interval='1m')
EW = yf.download(tickers= " EW ", period='1d', interval='1m')
EA = yf.download(tickers= " EA ", period='1d', interval='1m')
EMR = yf.download(tickers= " EMR ", period='1d', interval='1m')
ENPH = yf.download(tickers= " ENPH ", period='1d', interval='1m')
ETR = yf.download(tickers= " ETR ", period='1d', interval='1m')
EOG = yf.download(tickers= " EOG ", period='1d', interval='1m')
EFX = yf.download(tickers= " EFX ", period='1d', interval='1m')
EQIX = yf.download(tickers= " EQIX ", period='1d', interval='1m')
EQR = yf.download(tickers= " EQR ", period='1d', interval='1m')
ESS = yf.download(tickers= " ESS ", period='1d', interval='1m')
EL = yf.download(tickers= " EL ", period='1d', interval='1m')
ETSY = yf.download(tickers= " ETSY ", period='1d', interval='1m')
EVRG = yf.download(tickers= " EVRG ", period='1d', interval='1m')
ES = yf.download(tickers= " ES ", period='1d', interval='1m')
RE = yf.download(tickers= " RE ", period='1d', interval='1m')
EXC = yf.download(tickers= " EXC ", period='1d', interval='1m')
EXPE = yf.download(tickers= " EXPE ", period='1d', interval='1m')
EXPD = yf.download(tickers= " EXPD ", period='1d', interval='1m')
EXR = yf.download(tickers= " EXR ", period='1d', interval='1m')
XOM = yf.download(tickers= " XOM ", period='1d', interval='1m')
FFIV = yf.download(tickers= " FFIV ", period='1d', interval='1m')
FB = yf.download(tickers= " FB ", period='1d', interval='1m')
FAST = yf.download(tickers= " FAST ", period='1d', interval='1m')
FRT = yf.download(tickers= " FRT ", period='1d', interval='1m')
FDX = yf.download(tickers= " FDX ", period='1d', interval='1m')
FIS = yf.download(tickers= " FIS ", period='1d', interval='1m')
FITB = yf.download(tickers= " FITB ", period='1d', interval='1m')
FE = yf.download(tickers= " FE ", period='1d', interval='1m')
FRC = yf.download(tickers= " FRC ", period='1d', interval='1m')
FISV = yf.download(tickers= " FISV ", period='1d', interval='1m')
FLT = yf.download(tickers= " FLT ", period='1d', interval='1m')
FLIR = yf.download(tickers= " FLIR ", period='1d', interval='1m')
FLS = yf.download(tickers= " FLS ", period='1d', interval='1m')
FMC = yf.download(tickers= " FMC ", period='1d', interval='1m')
F = yf.download(tickers= " F ", period='1d', interval='1m')
FTNT = yf.download(tickers= " FTNT ", period='1d', interval='1m')
FTV = yf.download(tickers= " FTV ", period='1d', interval='1m')
FBHS = yf.download(tickers= " FBHS ", period='1d', interval='1m')
FOXA = yf.download(tickers= " FOXA ", period='1d', interval='1m')
FOX = yf.download(tickers= " FOX ", period='1d', interval='1m')
BEN = yf.download(tickers= " BEN ", period='1d', interval='1m')
FCX = yf.download(tickers= " FCX ", period='1d', interval='1m')
GPS = yf.download(tickers= " GPS ", period='1d', interval='1m')
GRMN = yf.download(tickers= " GRMN ", period='1d', interval='1m')
IT = yf.download(tickers= " IT ", period='1d', interval='1m')
GD = yf.download(tickers= " GD ", period='1d', interval='1m')
GE = yf.download(tickers= " GE ", period='1d', interval='1m')
GIS = yf.download(tickers= " GIS ", period='1d', interval='1m')
GM = yf.download(tickers= " GM ", period='1d', interval='1m')
GPC = yf.download(tickers= " GPC ", period='1d', interval='1m')
GILD = yf.download(tickers= " GILD ", period='1d', interval='1m')
GL = yf.download(tickers= " GL ", period='1d', interval='1m')
GPN = yf.download(tickers= " GPN ", period='1d', interval='1m')
GS = yf.download(tickers= " GS ", period='1d', interval='1m')
GWW = yf.download(tickers= " GWW ", period='1d', interval='1m')
HAL = yf.download(tickers= " HAL ", period='1d', interval='1m')
HBI = yf.download(tickers= " HBI ", period='1d', interval='1m')
HIG = yf.download(tickers= " HIG ", period='1d', interval='1m')
HAS = yf.download(tickers= " HAS ", period='1d', interval='1m')
HCA = yf.download(tickers= " HCA ", period='1d', interval='1m')
PEAK = yf.download(tickers= " PEAK ", period='1d', interval='1m')
HSIC = yf.download(tickers= " HSIC ", period='1d', interval='1m')
HSY = yf.download(tickers= " HSY ", period='1d', interval='1m')
HES = yf.download(tickers= " HES ", period='1d', interval='1m')
HPE = yf.download(tickers= " HPE ", period='1d', interval='1m')
HLT = yf.download(tickers= " HLT ", period='1d', interval='1m')
HFC = yf.download(tickers= " HFC ", period='1d', interval='1m')
HOLX = yf.download(tickers= " HOLX ", period='1d', interval='1m')
HD = yf.download(tickers= " HD ", period='1d', interval='1m')
HON = yf.download(tickers= " HON ", period='1d', interval='1m')
HRL = yf.download(tickers= " HRL ", period='1d', interval='1m')
HST = yf.download(tickers= " HST ", period='1d', interval='1m')
HWM = yf.download(tickers= " HWM ", period='1d', interval='1m')
HPQ = yf.download(tickers= " HPQ ", period='1d', interval='1m')
HUM = yf.download(tickers= " HUM ", period='1d', interval='1m')
HBAN = yf.download(tickers= " HBAN ", period='1d', interval='1m')
HII = yf.download(tickers= " HII ", period='1d', interval='1m')
IEX = yf.download(tickers= " IEX ", period='1d', interval='1m')
IDXX = yf.download(tickers= " IDXX ", period='1d', interval='1m')
INFO = yf.download(tickers= " INFO ", period='1d', interval='1m')
ITW = yf.download(tickers= " ITW ", period='1d', interval='1m')
ILMN = yf.download(tickers= " ILMN ", period='1d', interval='1m')
INCY = yf.download(tickers= " INCY ", period='1d', interval='1m')
IR = yf.download(tickers= " IR ", period='1d', interval='1m')
INTC = yf.download(tickers= " INTC ", period='1d', interval='1m')
ICE = yf.download(tickers= " ICE ", period='1d', interval='1m')
IBM = yf.download(tickers= " IBM ", period='1d', interval='1m')
IP = yf.download(tickers= " IP ", period='1d', interval='1m')
IPG = yf.download(tickers= " IPG ", period='1d', interval='1m')
IFF = yf.download(tickers= " IFF ", period='1d', interval='1m')
INTU = yf.download(tickers= " INTU ", period='1d', interval='1m')
ISRG = yf.download(tickers= " ISRG ", period='1d', interval='1m')
IVZ = yf.download(tickers= " IVZ ", period='1d', interval='1m')
IPGP = yf.download(tickers= " IPGP ", period='1d', interval='1m')
IQV = yf.download(tickers= " IQV ", period='1d', interval='1m')
IRM = yf.download(tickers= " IRM ", period='1d', interval='1m')
JKHY = yf.download(tickers= " JKHY ", period='1d', interval='1m')
J = yf.download(tickers= " J ", period='1d', interval='1m')
JBHT = yf.download(tickers= " JBHT ", period='1d', interval='1m')
SJM = yf.download(tickers= " SJM ", period='1d', interval='1m')
JNJ = yf.download(tickers= " JNJ ", period='1d', interval='1m')
JCI = yf.download(tickers= " JCI ", period='1d', interval='1m')
JPM = yf.download(tickers= " JPM ", period='1d', interval='1m')
JNPR = yf.download(tickers= " JNPR ", period='1d', interval='1m')
KSU = yf.download(tickers= " KSU ", period='1d', interval='1m')
K = yf.download(tickers= " K ", period='1d', interval='1m')
KEY = yf.download(tickers= " KEY ", period='1d', interval='1m')
KEYS = yf.download(tickers= " KEYS ", period='1d', interval='1m')
KMB = yf.download(tickers= " KMB ", period='1d', interval='1m')
KIM = yf.download(tickers= " KIM ", period='1d', interval='1m')
KMI = yf.download(tickers= " KMI ", period='1d', interval='1m')
KLAC = yf.download(tickers= " KLAC ", period='1d', interval='1m')
KHC = yf.download(tickers= " KHC ", period='1d', interval='1m')
KR = yf.download(tickers= " KR ", period='1d', interval='1m')
LB = yf.download(tickers= " LB ", period='1d', interval='1m')
LHX = yf.download(tickers= " LHX ", period='1d', interval='1m')
LH = yf.download(tickers= " LH ", period='1d', interval='1m')
LRCX = yf.download(tickers= " LRCX ", period='1d', interval='1m')
LW = yf.download(tickers= " LW ", period='1d', interval='1m')
LVS = yf.download(tickers= " LVS ", period='1d', interval='1m')
LEG = yf.download(tickers= " LEG ", period='1d', interval='1m')
LDOS = yf.download(tickers= " LDOS ", period='1d', interval='1m')
LEN = yf.download(tickers= " LEN ", period='1d', interval='1m')
LLY = yf.download(tickers= " LLY ", period='1d', interval='1m')
LNC = yf.download(tickers= " LNC ", period='1d', interval='1m')
LIN = yf.download(tickers= " LIN ", period='1d', interval='1m')
LYV = yf.download(tickers= " LYV ", period='1d', interval='1m')
LKQ = yf.download(tickers= " LKQ ", period='1d', interval='1m')
LMT = yf.download(tickers= " LMT ", period='1d', interval='1m')
L = yf.download(tickers= " L ", period='1d', interval='1m')
LOW = yf.download(tickers= " LOW ", period='1d', interval='1m')
LUMN = yf.download(tickers= " LUMN ", period='1d', interval='1m')
LYB = yf.download(tickers= " LYB ", period='1d', interval='1m')
MTB = yf.download(tickers= " MTB ", period='1d', interval='1m')
MRO = yf.download(tickers= " MRO ", period='1d', interval='1m')
MPC = yf.download(tickers= " MPC ", period='1d', interval='1m')
MKTX = yf.download(tickers= " MKTX ", period='1d', interval='1m')
MAR = yf.download(tickers= " MAR ", period='1d', interval='1m')
MMC = yf.download(tickers= " MMC ", period='1d', interval='1m')
MLM = yf.download(tickers= " MLM ", period='1d', interval='1m')
MAS = yf.download(tickers= " MAS ", period='1d', interval='1m')
MA = yf.download(tickers= " MA ", period='1d', interval='1m')
MKC = yf.download(tickers= " MKC ", period='1d', interval='1m')
MXIM = yf.download(tickers= " MXIM ", period='1d', interval='1m')
MCD = yf.download(tickers= " MCD ", period='1d', interval='1m')
MCK = yf.download(tickers= " MCK ", period='1d', interval='1m')
MDT = yf.download(tickers= " MDT ", period='1d', interval='1m')
MRK = yf.download(tickers= " MRK ", period='1d', interval='1m')
MET = yf.download(tickers= " MET ", period='1d', interval='1m')
MTD = yf.download(tickers= " MTD ", period='1d', interval='1m')
MGM = yf.download(tickers= " MGM ", period='1d', interval='1m')
MCHP = yf.download(tickers= " MCHP ", period='1d', interval='1m')
MU = yf.download(tickers= " MU ", period='1d', interval='1m')
MSFT = yf.download(tickers= " MSFT ", period='1d', interval='1m')
MAA = yf.download(tickers= " MAA ", period='1d', interval='1m')
MHK = yf.download(tickers= " MHK ", period='1d', interval='1m')
TAP = yf.download(tickers= " TAP ", period='1d', interval='1m')
MDLZ = yf.download(tickers= " MDLZ ", period='1d', interval='1m')
MNST = yf.download(tickers= " MNST ", period='1d', interval='1m')
MCO = yf.download(tickers= " MCO ", period='1d', interval='1m')
MS = yf.download(tickers= " MS ", period='1d', interval='1m')
MOS = yf.download(tickers= " MOS ", period='1d', interval='1m')
MSI = yf.download(tickers= " MSI ", period='1d', interval='1m')
MSCI = yf.download(tickers= " MSCI ", period='1d', interval='1m')
NDAQ = yf.download(tickers= " NDAQ ", period='1d', interval='1m')
NTAP = yf.download(tickers= " NTAP ", period='1d', interval='1m')
NFLX = yf.download(tickers= " NFLX ", period='1d', interval='1m')
NWL = yf.download(tickers= " NWL ", period='1d', interval='1m')
NEM = yf.download(tickers= " NEM ", period='1d', interval='1m')
NWSA = yf.download(tickers= " NWSA ", period='1d', interval='1m')
NWS = yf.download(tickers= " NWS ", period='1d', interval='1m')
NEE = yf.download(tickers= " NEE ", period='1d', interval='1m')
NLSN = yf.download(tickers= " NLSN ", period='1d', interval='1m')
NKE = yf.download(tickers= " NKE ", period='1d', interval='1m')
NI = yf.download(tickers= " NI ", period='1d', interval='1m')
NSC = yf.download(tickers= " NSC ", period='1d', interval='1m')
NTRS = yf.download(tickers= " NTRS ", period='1d', interval='1m')
NOC = yf.download(tickers= " NOC ", period='1d', interval='1m')
NLOK = yf.download(tickers= " NLOK ", period='1d', interval='1m')
NCLH = yf.download(tickers= " NCLH ", period='1d', interval='1m')
NOV = yf.download(tickers= " NOV ", period='1d', interval='1m')
NRG = yf.download(tickers= " NRG ", period='1d', interval='1m')
NUE = yf.download(tickers= " NUE ", period='1d', interval='1m')
NVDA = yf.download(tickers= " NVDA ", period='1d', interval='1m')
NVR = yf.download(tickers= " NVR ", period='1d', interval='1m')
ORLY = yf.download(tickers= " ORLY ", period='1d', interval='1m')
OXY = yf.download(tickers= " OXY ", period='1d', interval='1m')
ODFL = yf.download(tickers= " ODFL ", period='1d', interval='1m')
OMC = yf.download(tickers= " OMC ", period='1d', interval='1m')
OKE = yf.download(tickers= " OKE ", period='1d', interval='1m')
ORCL = yf.download(tickers= " ORCL ", period='1d', interval='1m')
OTIS = yf.download(tickers= " OTIS ", period='1d', interval='1m')
PCAR = yf.download(tickers= " PCAR ", period='1d', interval='1m')
PKG = yf.download(tickers= " PKG ", period='1d', interval='1m')
PH = yf.download(tickers= " PH ", period='1d', interval='1m')
PAYX = yf.download(tickers= " PAYX ", period='1d', interval='1m')
PAYC = yf.download(tickers= " PAYC ", period='1d', interval='1m')
PYPL = yf.download(tickers= " PYPL ", period='1d', interval='1m')
PNR = yf.download(tickers= " PNR ", period='1d', interval='1m')
PBCT = yf.download(tickers= " PBCT ", period='1d', interval='1m')
PEP = yf.download(tickers= " PEP ", period='1d', interval='1m')
PKI = yf.download(tickers= " PKI ", period='1d', interval='1m')
PRGO = yf.download(tickers= " PRGO ", period='1d', interval='1m')
PFE = yf.download(tickers= " PFE ", period='1d', interval='1m')
PM = yf.download(tickers= " PM ", period='1d', interval='1m')
PSX = yf.download(tickers= " PSX ", period='1d', interval='1m')
PNW = yf.download(tickers= " PNW ", period='1d', interval='1m')
PXD = yf.download(tickers= " PXD ", period='1d', interval='1m')
PNC = yf.download(tickers= " PNC ", period='1d', interval='1m')
POOL = yf.download(tickers= " POOL ", period='1d', interval='1m')
PPG = yf.download(tickers= " PPG ", period='1d', interval='1m')
PPL = yf.download(tickers= " PPL ", period='1d', interval='1m')
PFG = yf.download(tickers= " PFG ", period='1d', interval='1m')
PG = yf.download(tickers= " PG ", period='1d', interval='1m')
PGR = yf.download(tickers= " PGR ", period='1d', interval='1m')
PLD = yf.download(tickers= " PLD ", period='1d', interval='1m')
PRU = yf.download(tickers= " PRU ", period='1d', interval='1m')
PEG = yf.download(tickers= " PEG ", period='1d', interval='1m')
PSA = yf.download(tickers= " PSA ", period='1d', interval='1m')
PHM = yf.download(tickers= " PHM ", period='1d', interval='1m')
PVH = yf.download(tickers= " PVH ", period='1d', interval='1m')
QRVO = yf.download(tickers= " QRVO ", period='1d', interval='1m')
PWR = yf.download(tickers= " PWR ", period='1d', interval='1m')
QCOM = yf.download(tickers= " QCOM ", period='1d', interval='1m')
DGX = yf.download(tickers= " DGX ", period='1d', interval='1m')
RL = yf.download(tickers= " RL ", period='1d', interval='1m')
RJF = yf.download(tickers= " RJF ", period='1d', interval='1m')
RTX = yf.download(tickers= " RTX ", period='1d', interval='1m')
O = yf.download(tickers= " O ", period='1d', interval='1m')
REG = yf.download(tickers= " REG ", period='1d', interval='1m')
REGN = yf.download(tickers= " REGN ", period='1d', interval='1m')
RF = yf.download(tickers= " RF ", period='1d', interval='1m')
RSG = yf.download(tickers= " RSG ", period='1d', interval='1m')
RMD = yf.download(tickers= " RMD ", period='1d', interval='1m')
RHI = yf.download(tickers= " RHI ", period='1d', interval='1m')
ROK = yf.download(tickers= " ROK ", period='1d', interval='1m')
ROL = yf.download(tickers= " ROL ", period='1d', interval='1m')
ROP = yf.download(tickers= " ROP ", period='1d', interval='1m')
ROST = yf.download(tickers= " ROST ", period='1d', interval='1m')
RCL = yf.download(tickers= " RCL ", period='1d', interval='1m')
SPGI = yf.download(tickers= " SPGI ", period='1d', interval='1m')
CRM = yf.download(tickers= " CRM ", period='1d', interval='1m')
SBAC = yf.download(tickers= " SBAC ", period='1d', interval='1m')
SLB = yf.download(tickers= " SLB ", period='1d', interval='1m')
STX = yf.download(tickers= " STX ", period='1d', interval='1m')
SEE = yf.download(tickers= " SEE ", period='1d', interval='1m')
SRE = yf.download(tickers= " SRE ", period='1d', interval='1m')
NOW = yf.download(tickers= " NOW ", period='1d', interval='1m')
SHW = yf.download(tickers= " SHW ", period='1d', interval='1m')
SPG = yf.download(tickers= " SPG ", period='1d', interval='1m')
SWKS = yf.download(tickers= " SWKS ", period='1d', interval='1m')
SLG = yf.download(tickers= " SLG ", period='1d', interval='1m')
SNA = yf.download(tickers= " SNA ", period='1d', interval='1m')
SO = yf.download(tickers= " SO ", period='1d', interval='1m')
LUV = yf.download(tickers= " LUV ", period='1d', interval='1m')
SWK = yf.download(tickers= " SWK ", period='1d', interval='1m')
SBUX = yf.download(tickers= " SBUX ", period='1d', interval='1m')
STT = yf.download(tickers= " STT ", period='1d', interval='1m')
STE = yf.download(tickers= " STE ", period='1d', interval='1m')
SYK = yf.download(tickers= " SYK ", period='1d', interval='1m')
SIVB = yf.download(tickers= " SIVB ", period='1d', interval='1m')
SYF = yf.download(tickers= " SYF ", period='1d', interval='1m')
SNPS = yf.download(tickers= " SNPS ", period='1d', interval='1m')
SYY = yf.download(tickers= " SYY ", period='1d', interval='1m')
TMUS = yf.download(tickers= " TMUS ", period='1d', interval='1m')
TROW = yf.download(tickers= " TROW ", period='1d', interval='1m')
TTWO = yf.download(tickers= " TTWO ", period='1d', interval='1m')
TPR = yf.download(tickers= " TPR ", period='1d', interval='1m')
TGT = yf.download(tickers= " TGT ", period='1d', interval='1m')
TEL = yf.download(tickers= " TEL ", period='1d', interval='1m')
FTI = yf.download(tickers= " FTI ", period='1d', interval='1m')
TDY = yf.download(tickers= " TDY ", period='1d', interval='1m')
TFX = yf.download(tickers= " TFX ", period='1d', interval='1m')
TER = yf.download(tickers= " TER ", period='1d', interval='1m')
TSLA = yf.download(tickers= " TSLA ", period='1d', interval='1m')
TXN = yf.download(tickers= " TXN ", period='1d', interval='1m')
TXT = yf.download(tickers= " TXT ", period='1d', interval='1m')
TMO = yf.download(tickers= " TMO ", period='1d', interval='1m')
TJX = yf.download(tickers= " TJX ", period='1d', interval='1m')
TSCO = yf.download(tickers= " TSCO ", period='1d', interval='1m')
TT = yf.download(tickers= " TT ", period='1d', interval='1m')
TDG = yf.download(tickers= " TDG ", period='1d', interval='1m')
TRV = yf.download(tickers= " TRV ", period='1d', interval='1m')
TFC = yf.download(tickers= " TFC ", period='1d', interval='1m')
TWTR = yf.download(tickers= " TWTR ", period='1d', interval='1m')
TYL = yf.download(tickers= " TYL ", period='1d', interval='1m')
TSN = yf.download(tickers= " TSN ", period='1d', interval='1m')
UDR = yf.download(tickers= " UDR ", period='1d', interval='1m')
ULTA = yf.download(tickers= " ULTA ", period='1d', interval='1m')
USB = yf.download(tickers= " USB ", period='1d', interval='1m')
UAA = yf.download(tickers= " UAA ", period='1d', interval='1m')
UA = yf.download(tickers= " UA ", period='1d', interval='1m')
UNP = yf.download(tickers= " UNP ", period='1d', interval='1m')
UAL = yf.download(tickers= " UAL ", period='1d', interval='1m')
UNH = yf.download(tickers= " UNH ", period='1d', interval='1m')
UPS = yf.download(tickers= " UPS ", period='1d', interval='1m')
URI = yf.download(tickers= " URI ", period='1d', interval='1m')
UHS = yf.download(tickers= " UHS ", period='1d', interval='1m')
UNM = yf.download(tickers= " UNM ", period='1d', interval='1m')
VLO = yf.download(tickers= " VLO ", period='1d', interval='1m')
VAR = yf.download(tickers= " VAR ", period='1d', interval='1m')
VTR = yf.download(tickers= " VTR ", period='1d', interval='1m')
VRSN = yf.download(tickers= " VRSN ", period='1d', interval='1m')
VRSK = yf.download(tickers= " VRSK ", period='1d', interval='1m')
VZ = yf.download(tickers= " VZ ", period='1d', interval='1m')
VRTX = yf.download(tickers= " VRTX ", period='1d', interval='1m')
VFC = yf.download(tickers= " VFC ", period='1d', interval='1m')
VIAC = yf.download(tickers= " VIAC ", period='1d', interval='1m')
VTRS = yf.download(tickers= " VTRS ", period='1d', interval='1m')
V = yf.download(tickers= " V ", period='1d', interval='1m')
VNT = yf.download(tickers= " VNT ", period='1d', interval='1m')
VNO = yf.download(tickers= " VNO ", period='1d', interval='1m')
VMC = yf.download(tickers= " VMC ", period='1d', interval='1m')
WRB = yf.download(tickers= " WRB ", period='1d', interval='1m')
WAB = yf.download(tickers= " WAB ", period='1d', interval='1m')
WMT = yf.download(tickers= " WMT ", period='1d', interval='1m')
WBA = yf.download(tickers= " WBA ", period='1d', interval='1m')
DIS = yf.download(tickers= " DIS ", period='1d', interval='1m')
WM = yf.download(tickers= " WM ", period='1d', interval='1m')
WAT = yf.download(tickers= " WAT ", period='1d', interval='1m')
WEC = yf.download(tickers= " WEC ", period='1d', interval='1m')
WFC = yf.download(tickers= " WFC ", period='1d', interval='1m')
WELL = yf.download(tickers= " WELL ", period='1d', interval='1m')
WST = yf.download(tickers= " WST ", period='1d', interval='1m')
WDC = yf.download(tickers= " WDC ", period='1d', interval='1m')
WU = yf.download(tickers= " WU ", period='1d', interval='1m')
WRK = yf.download(tickers= " WRK ", period='1d', interval='1m')
WY = yf.download(tickers= " WY ", period='1d', interval='1m')
WHR = yf.download(tickers= " WHR ", period='1d', interval='1m')
WMB = yf.download(tickers= " WMB ", period='1d', interval='1m')
WLTW = yf.download(tickers= " WLTW ", period='1d', interval='1m')
WYNN = yf.download(tickers= " WYNN ", period='1d', interval='1m')
XEL = yf.download(tickers= " XEL ", period='1d', interval='1m')
XRX = yf.download(tickers= " XRX ", period='1d', interval='1m')
XLNX = yf.download(tickers= " XLNX ", period='1d', interval='1m')
XYL = yf.download(tickers= " XYL ", period='1d', interval='1m')
YUM = yf.download(tickers= " YUM ", period='1d', interval='1m')
ZBRA = yf.download(tickers= " ZBRA ", period='1d', interval='1m')
ZBH = yf.download(tickers= " ZBH ", period='1d', interval='1m')
ZION = yf.download(tickers= " ZION ", period='1d', interval='1m')
ZTS = yf.download(tickers= " ZTS ", period='1d', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
